# %%
from __future__ import division, print_function

# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

from matplotlib import rcParams
rcParams["savefig.dpi"] = 100
rcParams["font.size"] = 16

# %%
import os
import numpy as np
import matplotlib.pyplot as pl
from matplotlib.ticker import MaxNLocator

# %%
import turnstile

# %%
lc_dir = "../../k2/lightcurves/"
epicid = "201374602"
fn = lc_dir + "c1/{0}00000/{1}000/ktwo{2}-c01_lpd-lc.fits".format(epicid[:4], epicid[4:6], epicid)
basis = lc_dir + "c1-basis.h5"

# %%
pipe = turnstile.K2Data(basepath="./cache")
pipe = turnstile.K2Inject(pipe)
pipe = turnstile.K2Likelihood(pipe)
pipe = turnstile.OneDSearch(pipe)
pipe = turnstile.TwoDSearch(pipe)
pipe = turnstile.PeakDetect(pipe)

# %%
q = dict(
    light_curve_file=fn,
    basis_file=basis,
    injections=[dict(
        period=18.0, t0=12.4, radius=0.02,
    )],
    time_spacing=0.01,
    durations=[0.1],
    min_period=10.,
    max_period=70.,
    alpha=np.log(3500.)-np.log(2*np.pi),
)

# %%
r = pipe.query(**q)
# Out:
# WARNING:root:Not enough peaks were found
# Using cached value in TwoDSearch
# Querying PeakDetect
# Using cached value in OneDSearch
# Finished querying PeakDetect in 1.09s

# %%
lc = r.model_light_curves[0]

# %%
mu = lc.predict()

# %%
pl.plot(lc.time, lc.flux-mu, ".k")

# %%
pl.plot(r.depth_1d)

# %%
fig = pl.figure(figsize=(6, 3))
ax = pl.axes([0.15, 0.15, 0.8, 0.8])

ax.plot(r.period_2d, r.phic_same, "k", lw=0.7)

args = dict(xycoords="data", xytext=(0, 15), textcoords="offset points",
            ha="center", va="bottom", fontsize=12,
            arrowprops=dict(arrowstyle="-", shrinkA=0.0, shrinkB=6))
    
peak = r.peaks[0]
ax.annotate("first", xy=(peak["period"], peak["phic_same"]), **args)

peak = r.peaks[1]
ax.annotate("second", xy=(peak["period"], peak["phic_same"]), **args)

ax.set_ylim(0, 110)
ax.set_xlim(11, 69)
ax.yaxis.set_major_locator(MaxNLocator(5))
ax.set_xlabel("period [days]")
ax.set_ylabel("objective")
fig.savefig("periodic.pdf")

# %%
# Out:
# Using cached value in K2Likelihood
# Using cached value in K2Inject
# Using cached value in K2Data
# [{'curve_phic': -120187.74841345928,
#   'delta_phic': 28.40391734646591,
#   'depth': 0.48423408112382405,
#   'depth_ivar': 635.62737750647148,
#   'depth_s2n': 12.208340956767941,
#   'duration': 0.10000000000000001,
#   'period': 17.994272708807895,
#   'phic_norm': 66.509047484943096,
#   'phic_same': 81.484045591091515,
#   'phic_variable': 73.055823066646624,
#   'rms': 2.2649045782598343,
#   't0': 12.412084960937509},
#  {'curve_phic': -17714.706056456354,
#   'delta_phic': 22.377357634236617,
#   'depth': 0.48048165123236336,
#   'depth_ivar': 226.05156593785327,
#   'depth_s2n': 7.2240470740444946,
#   'duration': 0.10000000000000001,
#   'period': 65.784256570112959,
#   'phic_norm': 19.347858738776946,
#   'phic_same': 27.647772314772169,
#   'phic_variable': 26.63689376436832,
#   'rms': 2.2649045782598343,
#   't0': 15.26208496093755},
#  {'curve_phic': -36494.852740959606,
#   'delta_phic': 3.4995200068660068,
#   'depth': 0.089479084273487497,
#   'depth_ivar': 1288.7966401502376,
#   'depth_s2n': 3.2122824759722297,
#   'duration': 0.10000000000000001,
#   'period': 10.838853293914053,
#   'phic_norm': 1.2690487045177576,
#   'phic_same': 22.309924009361428,
#   'phic_variable': 2.8604143621308715,
#   'rms': 2.2649045782598343,
#   't0': 3.6620849609374986},
#  {'curve_phic': -49719.930827950433,
#   'delta_phic': 4.6811362637402425,
#   'depth': 0.14505533656803749,
#   'depth_ivar': 674.63811857972757,
#   'depth_s2n': 3.7676378322279902,
#   'duration': 0.10000000000000001,
#   'period': 17.8465637493359,
#   'phic_norm': 1.1262827190303444,
#   'phic_same': 16.177329926815435,
#   'phic_variable': 5.4626003788457886,
#   'rms': 2.2649045782598343,
#   't0': 9.0620849609374829},
#  {'curve_phic': -72053.195231669815,
#   'delta_phic': 2.2290609861894453,
#   'depth': 0.11285903344358826,
#   'depth_ivar': 978.28976744295403,
#   'depth_s2n': 3.5299624209137024,
#   'duration': 0.10000000000000001,
#   'period': 12.187442220289606,
#   'phic_norm': 0.96123218083887352,
#   'phic_same': 20.314156480761707,
#   'phic_variable': 3.6447636997081645,
#   'rms': 2.2649045782598343,
#   't0': 3.3620849609375014},
#  {'curve_phic': -10980.978138899891,
#   'delta_phic': 2.0177554905892219,
#   'depth': 0.1649215196009495,
#   'depth_ivar': 427.38115493029613,
#   'depth_s2n': 3.4094553862616461,
#   'duration': 0.10000000000000001,
#   'period': 29.683775179954836,
#   'phic_norm': -1.2772859442070832,
#   'phic_same': 10.079294034626319,
#   'phic_variable': 4.4700805393389444,
#   'rms': 2.2649045782598343,
#   't0': 18.212084960937592},
#  {'curve_phic': -14933.184161885707,
#   'delta_phic': 4.1458446367258706,
#   'depth': 0.12298334377495039,
#   'depth_ivar': 668.26931811724796,
#   'depth_s2n': 3.1792308050110547,
#   'duration': 0.10000000000000001,
#   'period': 17.203179229953587,
#   'phic_norm': -1.391748982501344,
#   'phic_same': 14.00578242946464,
#   'phic_variable': 1.6114101161324541,
#   'rms': 2.2649045782598343,
#   't0': 2.5620849609374972},
#  {'curve_phic': -2326.4981862691466,
#   'delta_phic': 2.3497131695593829,
#   'depth': 0.18969053512878581,
#   'depth_ivar': 299.03292836750938,
#   'depth_s2n': 3.2802365891915382,
#   'duration': 0.10000000000000001,
#   'period': 54.342327934348596,
#   'phic_norm': -1.6146378107799171,
#   'phic_same': 7.2144700920711751,
#   'phic_variable': 4.0854475346986403,
#   'rms': 2.2649045782598343,
#   't0': 7.0620849609374901},
#  {'curve_phic': -14750.609513310057,
#   'delta_phic': 2.694387694388773,
#   'depth': 0.11516109560788239,
#   'depth_ivar': 650.50237727019407,
#   'depth_s2n': 2.9371777659104148,
#   'duration': 0.10000000000000001,
#   'period': 22.74207294764874,
#   'phic_norm': -1.7224366090009244,
#   'phic_same': 11.334315738131624,
#   'phic_variable': 4.3174867721116446,
#   'rms': 2.2649045782598343,
#   't0': 5.7620849609374929},
#  {'curve_phic': -1021.0825057259226,
#   'delta_phic': 1.4094974750009159,
#   'depth': 0.1597457576008752,
#   'depth_ivar': 332.19351626472337,
#   'depth_s2n': 2.9115544014501253,
#   'duration': 0.10000000000000001,
#   'period': 53.614290568331498,
#   'phic_norm': -2.680678880743427,
#   'phic_same': 6.1897443327187798,
#   'phic_variable': 3.0309544275548044,
#   'rms': 2.2649045782598343,
#   't0': 10.962084960937489},
#  {'curve_phic': -3532.6304904561289,
#   'delta_phic': 1.3848015520402859,
#   'depth': 0.10798064458299179,
#   'depth_ivar': 483.74702899042018,
#   'depth_s2n': 2.3749532821235411,
#   'duration': 0.10000000000000001,
#   'period': 35.545463610602248,
#   'phic_norm': -3.1566961297799141,
#   'phic_same': 7.281349146295276,
#   'phic_variable': 1.0309358572817544,
#   'rms': 2.2649045782598343,
#   't0': 10.462084960937482},
#  {'curve_phic': -393.92287490760873,
#   'delta_phic': 0.51968047864827316,
#   'depth': 0.13943836495203848,
#   'depth_ivar': 312.57049115204291,
#   'depth_s2n': 2.4652233306409563,
#   'duration': 0.10000000000000001,
#   'period': 63.388921720009762,
#   'phic_norm': -3.4658665262909407,
#   'phic_same': 4.9290215577999801,
#   'phic_variable': 1.7789601456603839,
#   'rms': 2.2649045782598343,
#   't0': 11.162084960937491},
#  {'curve_phic': -2846.7575163255319,
#   'delta_phic': 0.96551376670127631,
#   'depth': 0.11056649787032428,
#   'depth_ivar': 435.14839032660871,
#   'depth_s2n': 2.306440441613312,
#   'duration': 0.10000000000000001,
#   'period': 35.174522731678962,
#   'phic_norm': -3.5387114773811659,
#   'phic_same': 6.9483871242225499,
#   'phic_variable': 0.9275365667763964,
#   'rms': 2.2649045782598343,
#   't0': 7.9620849609374886},
#  {'curve_phic': -87.826227204697958,
#   'delta_phic': 0.76606393865195344,
#   'depth': 0.16273611160782891,
#   'depth_ivar': 295.00999859852288,
#   'depth_s2n': 2.7951318733772439,
#   'duration': 0.10000000000000001,
#   'period': 44.372142349296396,
#   'phic_norm': -3.7792006815521475,
#   'phic_same': 5.7335524087321748,
#   'phic_variable': 2.6623108611109716,
#   'rms': 2.2649045782598343,
#   't0': 30.712084960937769}]
